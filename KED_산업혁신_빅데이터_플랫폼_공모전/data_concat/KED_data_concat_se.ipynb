# %% [markdown]
# 세분류

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
import pandas as pd

train=pd.read_csv('/content/drive/MyDrive/애쓰는 감자/data/train.csv',dtype={'KEDCD':str,'BZ_PPOS_ITM_CTT':str,'KSIC10_BZC_CD':str,'mid':str,'Big':str})
plus = pd.read_csv('/content/drive/MyDrive/애쓰는 감자/data/Augmentation_data.csv')

# %%
train=pd.read_csv('/content/drive/MyDrive/애쓰는 감자/data/train.csv',dtype={'KEDCD':str,'BZ_PPOS_ITM_CTT':str,'KSIC10_BZC_CD':str,'mid':str,'Big':str})

# %%
import re
plus["BZ_PPOS_ITM_CTT"] = plus["Dis"].str.replace('[^\w\s]', '', regex=True)
plus.head()
# Out:
#                               Dis Target            BZ_PPOS_ITM_CTT
# 0              농업, 임업 및 어업(01~03)      A             농업 임업 및 어업0103
# 1                       광업(05~08)      B                     광업0508
# 2                      제조업(10~34)      C                    제조업1034
# 3      전기, 가스, 증기 및 공기 조절 공급업(35)      D     전기 가스 증기 및 공기 조절 공급업35
# 4  수도, 하수 및 폐기물 처리, 원료 재생업(36~39)      E  수도 하수 및 폐기물 처리 원료 재생업3639

# %%
plus["BZ_PPOS_ITM_CTT"] = plus["BZ_PPOS_ITM_CTT"].str.replace('[0-9]+', '', regex=True)
plus.head()
# Out:
#                               Dis Target        BZ_PPOS_ITM_CTT
# 0              농업, 임업 및 어업(01~03)      A             농업 임업 및 어업
# 1                       광업(05~08)      B                     광업
# 2                      제조업(10~34)      C                    제조업
# 3      전기, 가스, 증기 및 공기 조절 공급업(35)      D   전기 가스 증기 및 공기 조절 공급업
# 4  수도, 하수 및 폐기물 처리, 원료 재생업(36~39)      E  수도 하수 및 폐기물 처리 원료 재생업

# %%
plus["se"] = plus["Target"].str[1:5]
plus
# Out:
#                                  Dis  Target        BZ_PPOS_ITM_CTT    se
# 0                 농업, 임업 및 어업(01~03)       A             농업 임업 및 어업
# 1                          광업(05~08)       B                     광업
# 2                         제조업(10~34)       C                    제조업
# 3         전기, 가스, 증기 및 공기 조절 공급업(35)       D   전기 가스 증기 및 공기 조절 공급업
# 4     수도, 하수 및 폐기물 처리, 원료 재생업(36~39)       E  수도 하수 및 폐기물 처리 원료 재생업
# ...                              ...     ...                    ...   ...
# 2016                       가구 내 고용활동  T97000              가구 내 고용활동  9700
# 2017              자가 소비를 위한 가사 생산 활동  T98100     자가 소비를 위한 가사 생산 활동  9810
# 2018             자가 소비를 위한 가사 서비스 활동  T98200    자가 소비를 위한 가사 서비스 활동  9820
# 2019                        주한 외국 공관  U99001               주한 외국 공관  9900
# 2020                    기타 국제 및 외국기관  U99009           기타 국제 및 외국기관  9900
#
# [2021 rows x 4 columns]

# %%
# 추가내용 파일 - 해당 분류에 맞게 삭제 
for i in range(len(plus)):
  if len(plus['se'][i])<4:
    plus=plus.drop(index=i)

print(len(plus))
# Out:
# 1691

# %%
plus['se'].unique()
# Out:
# array(['0111', '0112', '0113', '0114', '0115', '0121', '0122', '0123',
#        '6122', '6129', '6201', '6202', '6209', '6311', '6312', '6391',
#        '6399', '6411', '6412', '6413', '6420', '6491', '6499', '6511',
#        '6512', '6513', '6520', '6530', '6611', '6612', '6619', '6620',
#        '6811', '6812', '6821', '6822', '7011', '7012', '7013', '7020',
#        '7110', '7120', '7131', '7139', '7140', '7151', '7153', '7160',
#        '7211', '7212', '7291', '7292', '7310', '7320', '7330', '7390',
#        '7410', '7421', '7422', '7430', '7511', '7512', '7521', '7529',
#        '7531', '7532', '7533', '7591', '7599', '7611', '7619', '7621',
#        '7622', '7629', '7631', '7632', '7639', '7640', '8411', '8412',
#        '8421', '8422', '8431', '8432', '8440', '8450', '8511', '8512',
#        '8521', '8522', '8530', '8541', '8542', '8543', '8550', '8561',
#        '8562', '8563', '8564', '8565', '8566', '8569', '8570', '8610',
#        '8620', '8630', '8690', '8711', '8712', '8713', '8721', '8729',
#        '9011', '9012', '9013', '9019', '9021', '9022', '9023', '9029',
#        '9111', '9112', '9113', '9119', '9121', '9122', '9123', '9124',
#        '9129', '9411', '9412', '9420', '9491', '9492', '9493', '9499',
#        '9511', '9512', '9521', '9522', '9531', '9539', '9611', '9612',
#        '9691', '9692', '9699', '9700', '9810', '9820', '9900'],
#       dtype=object)

# %%
data_se = plus.loc[:,['BZ_PPOS_ITM_CTT', 'se']]
data_se.tail()
# Out:
#           BZ_PPOS_ITM_CTT    se
# 2016            가구 내 고용활동  9700
# 2017   자가 소비를 위한 가사 생산 활동  9810
# 2018  자가 소비를 위한 가사 서비스 활동  9820
# 2019             주한 외국 공관  9900
# 2020         기타 국제 및 외국기관  9900

# %%
len(data_se)
# Out:
# 1691

# %%
train.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ... Big    se
# 0  7695516.0   농산물 판매업  전자상거래업  통신판매업농임산물 건강기능식품 건강보조식품 일반식품...  ...   G  4620
# 1  8177802.0   건축공사업  토목공사업  토공사업  토목건축공사업  철근콘크리트공사업  실내인테리...  ...   F  4122
# 2  8233352.0   음식점업 경양식 퓨전 한식 중식 일식  식품 제조 가공 유통 판매 도소매업  제과...  ...   I  5611
# 3   991833.0   변호사의 직무에 속하는 업무  공증인의 직무에 속하는 업무  변호사법 제조에 속하...  ...   M  7110
# 4  7305137.0          일반폐기물처리업  재활용사업  정화조 청소업  위 각항에 부대되는 사업일체  ...   E  3821
#
# [5 rows x 6 columns]

# %%
for i in range(len(train)):
  if len(train['KSIC10_BZC_CD'][i])<5:
    train=train.drop(index=i)

print(len(train))
# Out:
# 1121101

# %%
train['se']=train['KSIC10_BZC_CD'].str[1:5]
train.head()
# Out:
#        KEDCD                                    BZ_PPOS_ITM_CTT  ... Big    se
# 0  7695516.0   농산물 판매업  전자상거래업  통신판매업농임산물 건강기능식품 건강보조식품 일반식품...  ...   G  4620
# 1  8177802.0   건축공사업  토목공사업  토공사업  토목건축공사업  철근콘크리트공사업  실내인테리...  ...   F  4122
# 2  8233352.0   음식점업 경양식 퓨전 한식 중식 일식  식품 제조 가공 유통 판매 도소매업  제과...  ...   I  5611
# 3   991833.0   변호사의 직무에 속하는 업무  공증인의 직무에 속하는 업무  변호사법 제조에 속하...  ...   M  7110
# 4  7305137.0          일반폐기물처리업  재활용사업  정화조 청소업  위 각항에 부대되는 사업일체  ...   E  3821
#
# [5 rows x 6 columns]

# %%
train.tail()
# Out:
#              KEDCD                                    BZ_PPOS_ITM_CTT  ... Big    se
# 1139563  5063548.0   토목 공사업  건축 공사업  토목건축 공사업  주택 건설업  오수정화시설설계 시공...  ...   F  4111
# 1139564  8210358.0   일반음식점업  식품 수입수출업  식품 유통업  출판업  도서판매업  부동산매매업 ...  ...   I  5611
# 1139565   805153.0   절전형 보일러 시스템 제조 및 도소매업  토목공사업  주택건축공사업  택지조성 및...  ...   G  4781
# 1139566  7449392.0    레미콘 제조업   레미콘 판매업   골재납품업   레미콘 및 골재 운반업   건...  ...   C  2332
# 1139567   709887.0   환경보호 및 공해방지 사업  폐기물 해상처리업  폐기물 육상처리업  건설자재 운반...  ...   E  3812
#
# [5 rows x 6 columns]

# %%
len(train)
# Out:
# 1121101

# %%
trn = pd.concat([train, data_se], ignore_index = True)
trn.tail()
# Out:
#         KEDCD      BZ_PPOS_ITM_CTT KSIC10_BZC_CD  mid  Big    se
# 1122787   NaN            가구 내 고용활동           NaN  NaN  NaN  9700
# 1122788   NaN   자가 소비를 위한 가사 생산 활동           NaN  NaN  NaN  9810
# 1122789   NaN  자가 소비를 위한 가사 서비스 활동           NaN  NaN  NaN  9820
# 1122790   NaN             주한 외국 공관           NaN  NaN  NaN  9900
# 1122791   NaN         기타 국제 및 외국기관           NaN  NaN  NaN  9900

# %%
trn = trn.loc[:,['BZ_PPOS_ITM_CTT', 'se']]
trn.tail()
# Out:
#              BZ_PPOS_ITM_CTT    se
# 1122787            가구 내 고용활동  9700
# 1122788   자가 소비를 위한 가사 생산 활동  9810
# 1122789  자가 소비를 위한 가사 서비스 활동  9820
# 1122790             주한 외국 공관  9900
# 1122791         기타 국제 및 외국기관  9900

# %%
trn =trn.dropna(axis=0)
len(trn)
# Out:
# 1122792

# %%
trn_shuffle = trn.sample(frac=1).reset_index(drop=True)
trn_shuffle.tail()
# Out:
#                                            BZ_PPOS_ITM_CTT    se
# 1122787   시설물유지관리업  철근콘크리트공사업  건축공사업  주택건설업  교량구조물제작설치업...  4122
# 1122788   가구 제조 도소매 수출입업  철재가구 제조 도소매 수출입업  목재 제재 및 도소매...  3209
# 1122789  기타사업관련서비스업 사업중개주선업 소프트웨어 개발 및 판매업 온라인 정보 제공업 온...  5822
# 1122790  협동조합은 자주적자립적자치적인 협동조합 활동을 통하여 구성원의 복리증진과 상부상조 ...  9499
# 1122791                 광고마케팅업  광고기획업  광고대행업  각 호에 부대하는 사업  7131

# %%
trn_shuffle['se'].unique()
# Out:
#        '2925', '9012', '3831', '9023', '0729', '1080', '9539', '7430',
#        '4742', '9522', '5020', '3402', '1629', '1075', '2225', '1050',
#        '8522', '1430', '1340', '4783', '8561', '1420', '1522', '3033',
#        '2322', '1910', '2915', '6513', '7013', '3512', '1062', '7632',
#        '5613', '7422', '0122', '2841', '9129', '2312', '2916', '9123',
#        '7639', '1921', '0312', '2923', '4751', '5012', '1441', '4762',
#        '7591', '9021', '9512', '6121', '8712', '6412', '2740', '9900',
#        '8713', '1011', '1519', '2323', '7533', '2591', '1412', '0722',
#        '4910', '1413', '2611', '8422', '4752', '2918', '2660', '3040',
#        '2319', '1073', '7532', '7151', '6391', '2926', '5011', '1820',
#        '2711', '7629', '3112', '2331', '4711', '3031', '7619', '0203',
#        '4722', '0620', '4713', '3320', '1391', '5293', '2321', '5120',
#        '9013', '2513', '8432', '8512', '8565', '0510', '2211', '2013',
#        '2123', '2520', '1112', '7310', '0520', '1630', '8511', '9029',
#        '2122', '4522', '4792', '3011', '7622', '3530', '6511', '9111',
#        '8440', '4950', '9011', '1200', '0322', '3602', '1711', '6021',
#        '5110', '9124', '6530', '0721', '8411', '8543', '3601', '3824',
#        '6010', '8542', '9820', '8541', '6520', '8412', '6411', '6611',
#        '0150', '8431', '9700', '3191', '8450', '9492', '9810'],
#       dtype=object)

# %%
trn_shuffle.to_csv('/content/drive/MyDrive/애쓰는 감자/data/mid_data/train_data_se.csv', index = False)

# %%
# 라벨링
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(trn_shuffle['se'])
trn_shuffle['se_idx'] = encoder.transform(trn_shuffle['se'])
trn_shuffle.head()
# Out:
#                                      BZ_PPOS_ITM_CTT    se  se_idx
# 0   황토 매트 방석제조업                             황토 비누...  2890     165
# 1   부동산개발사업  부동산임대사업  부동산분양사업  인테리어업  위 각호에 부대하는 ...  6812     377
# 2   파이프 도소매업  파이프 가공제작업  철구조물 가공제작업  각항에 관련된 부대사업...  2413     124
# 3   영상보안기기 개발 제조 판매업  멀티미디어 하드웨어 소프트웨어 개발 서비스업  유...  7012     381
# 4   산업설비 공사업  택지 조성개발사업  부동산 개발업  토목 건축 공사업  건축 공...  4122     236

# %%
# 라벨링된 것 매핑
mapping = dict(zip(range(len(encoder.classes_)), encoder.classes_))
mapping
# Out:
# {0: '0111',
#  1: '0112',
#  2: '0113',
#  3: '0114',
#  4: '0115',
#  5: '0121',
#  6: '0122',
#  7: '0123',
#  8: '0129',
#  9: '0130',
#  10: '0141',
#  11: '0142',
#  12: '0150',
#  13: '0201',
#  14: '0202',
#  15: '0203',
#  16: '0204',
#  17: '0311',
#  18: '0312',
#  19: '0321',
#  20: '0322',
#  21: '0510',
#  22: '0520',
#  23: '0610',
#  24: '0620',
#  25: '0711',
#  26: '0712',
#  27: '0721',
#  28: '0722',
#  29: '0729',
#  30: '0800',
#  31: '1011',
#  32: '1012',
#  33: '1021',
#  34: '1022',
#  35: '1030',
#  36: '1040',
#  37: '1050',
#  38: '1061',
#  39: '1062',
#  40: '1071',
#  41: '1072',
#  42: '1073',
#  43: '1074',
#  44: '1075',
#  45: '1079',
#  46: '1080',
#  47: '1111',
#  48: '1112',
#  49: '1120',
#  50: '1200',
#  51: '1310',
#  52: '1321',
#  53: '1322',
#  54: '1330',
#  55: '1340',
#  56: '1391',
#  57: '1392',
#  58: '1399',
#  59: '1411',
#  60: '1412',
#  61: '1413',
#  62: '1419',
#  63: '1420',
#  64: '1430',
#  65: '1441',
#  66: '1449',
#  67: '1511',
#  68: '1512',
#  69: '1519',
#  70: '1521',
#  71: '1522',
#  72: '1610',
#  73: '1621',
#  74: '1622',
#  75: '1623',
#  76: '1629',
#  77: '1630',
#  78: '1711',
#  79: '1712',
#  80: '1721',
#  81: '1722',
#  82: '1790',
#  83: '1811',
#  84: '1812',
#  85: '1820',
#  86: '1910',
#  87: '1921',
#  88: '1922',
#  89: '2011',
#  90: '2012',
#  91: '2013',
#  92: '2020',
#  93: '2031',
#  94: '2032',
#  95: '2041',
#  96: '2042',
#  97: '2049',
#  98: '2050',
#  99: '2110',
#  100: '2121',
#  101: '2122',
#  102: '2123',
#  103: '2130',
#  104: '2211',
#  105: '2219',
#  106: '2221',
#  107: '2222',
#  108: '2223',
#  109: '2224',
#  110: '2225',
#  111: '2229',
#  112: '2311',
#  113: '2312',
#  114: '2319',
#  115: '2321',
#  116: '2322',
#  117: '2323',
#  118: '2331',
#  119: '2332',
#  120: '2391',
#  121: '2399',
#  122: '2411',
#  123: '2412',
#  124: '2413',
#  125: '2419',
#  126: '2421',
#  127: '2422',
#  128: '2429',
#  129: '2431',
#  130: '2432',
#  131: '2511',
#  132: '2512',
#  133: '2513',
#  134: '2520',
#  135: '2591',
#  136: '2592',
#  137: '2593',
#  138: '2594',
#  139: '2599',
#  140: '2611',
#  141: '2612',
#  142: '2621',
#  143: '2622',
#  144: '2629',
#  145: '2631',
#  146: '2632',
#  147: '2641',
#  148: '2642',
#  149: '2651',
#  150: '2652',
#  151: '2660',
#  152: '2711',
#  153: '2719',
#  154: '2721',
#  155: '2730',
#  156: '2740',
#  157: '2811',
#  158: '2812',
#  159: '2820',
#  160: '2830',
#  161: '2841',
#  162: '2842',
#  163: '2851',
#  164: '2852',
#  165: '2890',
#  166: '2911',
#  167: '2912',
#  168: '2913',
#  169: '2914',
#  170: '2915',
#  171: '2916',
#  172: '2917',
#  173: '2918',
#  174: '2919',
#  175: '2921',
#  176: '2922',
#  177: '2923',
#  178: '2924',
#  179: '2925',
#  180: '2926',
#  181: '2927',
#  182: '2928',
#  183: '2929',
#  184: '3011',
#  185: '3012',
#  186: '3020',
#  187: '3031',
#  188: '3032',
#  189: '3033',
#  190: '3039',
#  191: '3040',
#  192: '3111',
#  193: '3112',
#  194: '3120',
#  195: '3131',
#  196: '3132',
#  197: '3191',
#  198: '3192',
#  199: '3199',
#  200: '3201',
#  201: '3202',
#  202: '3209',
#  203: '3311',
#  204: '3312',
#  205: '3320',
#  206: '3330',
#  207: '3340',
#  208: '3391',
#  209: '3392',
#  210: '3393',
#  211: '3399',
#  212: '3401',
#  213: '3402',
#  214: '3511',
#  215: '3512',
#  216: '3513',
#  217: '3520',
#  218: '3530',
#  219: '3601',
#  220: '3602',
#  221: '3701',
#  222: '3702',
#  223: '3811',
#  224: '3812',
#  225: '3813',
#  226: '3821',
#  227: '3822',
#  228: '3823',
#  229: '3824',
#  230: '3831',
#  231: '3832',
#  232: '3900',
#  233: '4111',
#  234: '4112',
#  235: '4121',
#  236: '4122',
#  237: '4211',
#  238: '4212',
#  239: '4213',
#  240: '4220',
#  241: '4231',
#  242: '4232',
#  243: '4241',
#  244: '4242',
#  245: '4249',
#  246: '4250',
#  247: '4260',
#  248: '4511',
#  249: '4512',
#  250: '4521',
#  251: '4522',
#  252: '4530',
#  253: '4610',
#  254: '4620',
#  255: '4631',
#  256: '4632',
#  257: '4633',
#  258: '4641',
#  259: '4642',
#  260: '4643',
#  261: '4644',
#  262: '4645',
#  263: '4646',
#  264: '4649',
#  265: '4651',
#  266: '4652',
#  267: '4653',
#  268: '4659',
#  269: '4661',
#  270: '4662',
#  271: '4669',
#  272: '4671',
#  273: '4672',
#  274: '4673',
#  275: '4674',
#  276: '4675',
#  277: '4679',
#  278: '4680',
#  279: '4711',
#  280: '4712',
#  281: '4713',
#  282: '4719',
#  283: '4721',
#  284: '4722',
#  285: '4731',
#  286: '4732',
#  287: '4741',
#  288: '4742',
#  289: '4743',
#  290: '4744',
#  291: '4751',
#  292: '4752',
#  293: '4759',
#  294: '4761',
#  295: '4762',
#  296: '4763',
#  297: '4764',
#  298: '4771',
#  299: '4772',
#  300: '4781',
#  301: '4782',
#  302: '4783',
#  303: '4784',
#  304: '4785',
#  305: '4786',
#  306: '4791',
#  307: '4792',
#  308: '4799',
#  309: '4910',
#  310: '4921',
#  311: '4922',
#  312: '4923',
#  313: '4930',
#  314: '4940',
#  315: '4950',
#  316: '5011',
#  317: '5012',
#  318: '5013',
#  319: '5020',
#  320: '5110',
#  321: '5120',
#  322: '5210',
#  323: '5291',
#  324: '5292',
#  325: '5293',
#  326: '5294',
#  327: '5299',
#  328: '5510',
#  329: '5590',
#  330: '5611',
#  331: '5612',
#  332: '5613',
#  333: '5614',
#  334: '5619',
#  335: '5621',
#  336: '5622',
#  337: '5811',
#  338: '5812',
#  339: '5819',
#  340: '5821',
#  341: '5822',
#  342: '5911',
#  343: '5912',
#  344: '5913',
#  345: '5914',
#  346: '5920',
#  347: '6010',
#  348: '6021',
#  349: '6022',
#  350: '6110',
#  351: '6121',
#  352: '6122',
#  353: '6129',
#  354: '6201',
#  355: '6202',
#  356: '6209',
#  357: '6311',
#  358: '6312',
#  359: '6391',
#  360: '6399',
#  361: '6411',
#  362: '6412',
#  363: '6413',
#  364: '6420',
#  365: '6491',
#  366: '6499',
#  367: '6511',
#  368: '6512',
#  369: '6513',
#  370: '6520',
#  371: '6530',
#  372: '6611',
#  373: '6612',
#  374: '6619',
#  375: '6620',
#  376: '6811',
#  377: '6812',
#  378: '6821',
#  379: '6822',
#  380: '7011',
#  381: '7012',
#  382: '7013',
#  383: '7020',
#  384: '7110',
#  385: '7120',
#  386: '7131',
#  387: '7139',
#  388: '7140',
#  389: '7151',
#  390: '7153',
#  391: '7160',
#  392: '7211',
#  393: '7212',
#  394: '7291',
#  395: '7292',
#  396: '7310',
#  397: '7320',
#  398: '7330',
#  399: '7390',
#  400: '7410',
#  401: '7421',
#  402: '7422',
#  403: '7430',
#  404: '7511',
#  405: '7512',
#  406: '7521',
#  407: '7529',
#  408: '7531',
#  409: '7532',
#  410: '7533',
#  411: '7591',
#  412: '7599',
#  413: '7611',
#  414: '7619',
#  415: '7621',
#  416: '7622',
#  417: '7629',
#  418: '7631',
#  419: '7632',
#  420: '7639',
#  421: '7640',
#  422: '8411',
#  423: '8412',
#  424: '8421',
#  425: '8422',
#  426: '8431',
#  427: '8432',
#  428: '8440',
#  429: '8450',
#  430: '8511',
#  431: '8512',
#  432: '8521',
#  433: '8522',
#  434: '8530',
#  435: '8541',
#  436: '8542',
#  437: '8543',
#  438: '8550',
#  439: '8561',
#  440: '8562',
#  441: '8563',
#  442: '8564',
#  443: '8565',
#  444: '8566',
#  445: '8569',
#  446: '8570',
#  447: '8610',
#  448: '8620',
#  449: '8630',
#  450: '8690',
#  451: '8711',
#  452: '8712',
#  453: '8713',
#  454: '8721',
#  455: '8729',
#  456: '9011',
#  457: '9012',
#  458: '9013',
#  459: '9019',
#  460: '9021',
#  461: '9022',
#  462: '9023',
#  463: '9029',
#  464: '9111',
#  465: '9112',
#  466: '9113',
#  467: '9119',
#  468: '9121',
#  469: '9122',
#  470: '9123',
#  471: '9124',
#  472: '9129',
#  473: '9411',
#  474: '9412',
#  475: '9420',
#  476: '9491',
#  477: '9492',
#  478: '9493',
#  479: '9499',
#  480: '9511',
#  481: '9512',
#  482: '9521',
#  483: '9522',
#  484: '9531',
#  485: '9539',
#  486: '9611',
#  487: '9612',
#  488: '9691',
#  489: '9692',
#  490: '9699',
#  491: '9700',
#  492: '9810',
#  493: '9820',
#  494: '9900'}

# %%
trn_shuffle = trn_shuffle.loc[:,['BZ_PPOS_ITM_CTT', 'se_idx']]
trn_shuffle.head()
# Out:
#                                      BZ_PPOS_ITM_CTT  se_idx
# 0   황토 매트 방석제조업                             황토 비누...     165
# 1   부동산개발사업  부동산임대사업  부동산분양사업  인테리어업  위 각호에 부대하는 ...     377
# 2   파이프 도소매업  파이프 가공제작업  철구조물 가공제작업  각항에 관련된 부대사업...     124
# 3   영상보안기기 개발 제조 판매업  멀티미디어 하드웨어 소프트웨어 개발 서비스업  유...     381
# 4   산업설비 공사업  택지 조성개발사업  부동산 개발업  토목 건축 공사업  건축 공...     236

# %%
trn_shuffle.to_csv('/content/drive/MyDrive/애쓰는 감자/data/mid_data/train_se.txt', sep='\t', index=True)
